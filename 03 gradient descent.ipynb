# %% [markdown]
# # Note book Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Example 1- A simple cost function
#
# ## $$f(x) = x^2+x+1$$

# %%
def f(x):
    return x**2 + x + 1

# %%
# Make Data

x_1 = np.linspace(start=-3,stop=3,num=500)

# %%
# Plot
plt.xlim([-3,3])
plt.ylim(0,8)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.plot(x_1,f(x_1))
plt.show()

# %% [markdown]
# ## Slope and Derivatives

# %%
def df(x):
    return 2*x+1

# %%
# Plot function and derivative side by side

plt.figure(figsize=[15,5])


# 1st chart: cost function
plt.subplot(1,2,1)

plt.xlim([-3,3])
plt.ylim(0,8)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.plot(x_1,f(x_1),color='blue',linewidth=3)

# 2nd chart: derivative
plt.subplot(1,2,2)
plt.xlim(-2,3)
plt.ylim(-3,6)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5)


plt.show()

# %%
# Plot function and derivative side by side

plt.figure(figsize=[5,15])


# 1st chart: cost function
plt.subplot(2,1,1)

plt.xlim([-3,3])
plt.ylim(0,8)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.plot(x_1,f(x_1),color='blue',linewidth=3)

# 2nd chart: derivative
plt.subplot(2,1,2)
plt.xlim(-2,3)
plt.ylim(-3,6)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5)


plt.show()

# %% [markdown]
# ## Python loops and Gradient Descent

# %%
# Python for loop
for n in range(5):
    print('hello world',n)
print('end of loop')
# Out:
# hello world 0
# hello world 1
# hello world 2
# hello world 3
# hello world 4
# end of loop

# %%
# Python while loop
counter=0
while counter<7:
    print('counting....',counter)
    counter= counter+1
print('ready or not here i come')
# Out:
# counting.... 0
# counting.... 1
# counting.... 2
# counting.... 3
# counting.... 4
# counting.... 5
# counting.... 6
# ready or not here i come

# %%
# Gradient Descent
new_x=3
previous_x=0
step_multiplier=0.1
precision=0.00001

x_list =[new_x]
slope_list=[df(new_x)]

for n in range(500):
    previous_x=new_x
    gradient=df(previous_x)
    new_x=previous_x-step_multiplier*gradient

    step_size= abs(new_x-previous_x)

    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    if step_size<precision:
        print('loop ran this many times: ',n)
        break

print('local minimum occurs at: ',new_x)
print('df(x), slope value at this point is: ',df(new_x))
print('f(x), cost value at this point is : ',f(new_x))
# Out:
# loop ran this many times:  50
# local minimum occurs at:  -0.49996003706460423
# df(x), slope value at this point is:  7.992587079153068e-05
# f(x), cost value at this point is :  0.7500000015970362

# %%
# Super impose the gradient descent calculations

plt.figure(figsize=[20,5])


# 1st chart: cost function
plt.subplot(1,3,1)

plt.xlim([-3,3])
plt.ylim(0,8)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.plot(x_1,f(x_1),color='blue',linewidth=3,alpha=0.6)
values= np.array(x_list)
plt.scatter(x_list,f(values),color='r',s=100,alpha=0.6)

# 2nd chart: derivative
plt.subplot(1,3,2)
plt.xlim(-2,3)
plt.ylim(-3,6)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5,alpha=0.6)
plt.scatter(x_list,slope_list, color='r',s=100,alpha=0.5)

# 3rd chart: derivative closeup
plt.subplot(1,3,3)
plt.xlim(-0.55,-0.2)
plt.ylim(-0.3,0.8)
plt.grid()
plt.title('gradient descent close up',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)
plt.plot(x_1,df(x_1),color='green',linewidth=6,alpha=0.8)
plt.scatter(x_list,slope_list, color='r',s=300,alpha=0.5)


plt.show()

# %%
# Gradient Descent(rerun using -3 for new_x)
new_x=-3
previous_x=0
step_multiplier=0.1
precision=0.00001

x_list =[new_x]
slope_list=[df(new_x)]

for n in range(500):
    previous_x=new_x
    gradient=df(previous_x)
    new_x=previous_x-step_multiplier*gradient

    step_size= abs(new_x-previous_x)

    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    if step_size<precision:
        print('loop ran this many times: ',n)
        break

print('local minimum occurs at: ',new_x)
print('df(x), slope value at this point is: ',df(new_x))
print('f(x), cost value at this point is : ',f(new_x))
# Out:
# loop ran this many times:  49
# local minimum occurs at:  -0.5000356811923176
# df(x), slope value at this point is:  -7.136238463512079e-05
# f(x), cost value at this point is :  0.7500000012731475

# %%
# Super impose the gradient descent calculations(rerun using -3 for new_x)

plt.figure(figsize=[20,5])


# 1st chart: cost function
plt.subplot(1,3,1)

plt.xlim([-3,3])
plt.ylim(0,8)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.plot(x_1,f(x_1),color='blue',linewidth=3,alpha=0.6)
values= np.array(x_list)
plt.scatter(x_list,f(values),color='r',s=100,alpha=0.6)

# 2nd chart: derivative
plt.subplot(1,3,2)
plt.xlim(-2,3)
plt.ylim(-3,6)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5,alpha=0.6)
plt.scatter(x_list,slope_list, color='r',s=100,alpha=0.5)

# 3rd chart: derivative closeup
plt.subplot(1,3,3)
plt.xlim(-0.55,-0.2)
plt.ylim(-0.3,0.8)
plt.grid()
plt.title('gradient descent close up',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)
plt.plot(x_1,df(x_1),color='green',linewidth=6,alpha=0.8)
plt.scatter(x_list,slope_list, color='r',s=300,alpha=0.5)


plt.show()

# %%
# Gradient Descent(rerun using 10 in for loop)
new_x=3
previous_x=0
step_multiplier=0.1
precision=0.00001

x_list =[new_x]
slope_list=[df(new_x)]

for n in range(10):
    previous_x=new_x
    gradient=df(previous_x)
    new_x=previous_x-step_multiplier*gradient

    step_size= abs(new_x-previous_x)

    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    if step_size<precision:
        print('loop ran this many times: ',n)
        break

print('local minimum occurs at: ',new_x)
print('df(x), slope value at this point is: ',df(new_x))
print('f(x), cost value at this point is : ',f(new_x))
# Out:
# local minimum occurs at:  -0.12419036160000013
# df(x), slope value at this point is:  0.7516192767999997
# f(x), cost value at this point is :  0.8912328843143387

# %%
# Super impose the gradient descent calculations(rerun using 10 in for loop)

plt.figure(figsize=[20,5])


# 1st chart: cost function
plt.subplot(1,3,1)

plt.xlim([-3,3])
plt.ylim(0,8)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('f(x)',fontsize=16)
plt.plot(x_1,f(x_1),color='blue',linewidth=3,alpha=0.6)
values= np.array(x_list)
plt.scatter(x_list,f(values),color='r',s=100,alpha=0.6)

# 2nd chart: derivative
plt.subplot(1,3,2)
plt.xlim(-2,3)
plt.ylim(-3,6)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5,alpha=0.6)
plt.scatter(x_list,slope_list, color='r',s=100,alpha=0.5)

# 3rd chart: derivative closeup
plt.subplot(1,3,3)
plt.xlim(-0.55,-0.2)
plt.ylim(-0.3,0.8)
plt.grid()
plt.title('gradient descent close up',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('df(x)',fontsize=16)
plt.plot(x_1,df(x_1),color='green',linewidth=6,alpha=0.8)
plt.scatter(x_list,slope_list, color='r',s=300,alpha=0.5)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess and Advanced Functions
# ## $$g(x) = x^4-4x^2+5$$

# %%
# Make some data
x_2=np.linspace(-2,2,1000)

# %%
def g(x):
    return x**4-4*x**2+5

def dg(x):
    return 4*x**3-8*x

# %%
# Plot function and derivative side by side

plt.figure(figsize=[15,5])


# 1st chart: cost function
plt.subplot(1,2,1)

plt.xlim([-2,2])
plt.ylim(0.5,5.5)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)
plt.plot(x_2,g(x_2),color='blue',linewidth=3)

# 2nd chart: derivative
plt.subplot(1,2,2)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('dg(x)',fontsize=16)
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=5)


plt.show()

# %% [markdown]
# ## Gradient Descent as a Python Function

# %%
def gradient_descent(derivative_func,initial_guess,multiplier=0.02,precision=0.001,max_iter=300):

    new_x=initial_guess
    x_list =[new_x]
    slope_list=[derivative_func(new_x)]
    
    for n in range(max_iter):
        previous_x=new_x
        gradient=derivative_func(previous_x)
        new_x=previous_x-multiplier*gradient
    
        step_size= abs(new_x-previous_x)
    
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))
        
        if step_size<precision:
            break
    return new_x,x_list,slope_list

# %%
local_min,list_x,deriv_list = gradient_descent(dg,0.5,0.02,0.001)
print('local min occurs at: ',local_min)
print('number of steps: ',len(list_x))
# Out:
# local min occurs at:  1.4122375085019094
# number of steps:  23

# %%
#supplying arguments by keywords
local_min,list_x,deriv_list = gradient_descent(derivative_func=dg,initial_guess=-0.5,multiplier=0.01,
                                               precision=0.0001)
print('local min occurs at: ',local_min)
print('number of steps: ',len(list_x))
# Out:
# local min occurs at:  -1.4137636556157256
# number of steps:  56

# %%
#supplying arguments by keywords
local_min,list_x,deriv_list = gradient_descent(derivative_func=dg,initial_guess=-0.1)
print('local min occurs at: ',local_min)
print('number of steps: ',len(list_x))
# Out:
# local min occurs at:  -1.4120887490901561
# number of steps:  34

# %%
#calling gradient descent function

local_min,list_x,deriv_list = gradient_descent(derivative_func=dg,initial_guess=0.1)

# Plot function and derivative side by side

plt.figure(figsize=[15,5])


# 1st chart: cost function
plt.subplot(1,2,1)

plt.xlim([-2,2])
plt.ylim(0.5,5.5)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)
plt.plot(x_2,g(x_2),color='blue',linewidth=3, alpha = 0.8)
plt.scatter(list_x,g(np.array(list_x)),color='red',s=100,alpha=0.6)


# 2nd chart: derivative
plt.subplot(1,2,2)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('dg(x)',fontsize=16)
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=5,alpha=0.6)
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.5)


plt.show()

# %%
#calling gradient descent function

local_min,list_x,deriv_list = gradient_descent(derivative_func=dg,initial_guess=2)

# Plot function and derivative side by side(initial guess=2)

plt.figure(figsize=[15,5])


# 1st chart: cost function
plt.subplot(1,2,1)

plt.xlim([-2,2])
plt.ylim(0.5,5.5)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)
plt.plot(x_2,g(x_2),color='blue',linewidth=3, alpha = 0.8)
plt.scatter(list_x,g(np.array(list_x)),color='red',s=100,alpha=0.6)


# 2nd chart: derivative
plt.subplot(1,2,2)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('dg(x)',fontsize=16)
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=5,alpha=0.6)
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.5)


plt.show()

# %%
#calling gradient descent function

local_min,list_x,deriv_list = gradient_descent(derivative_func=dg,initial_guess=-1.8)

# Plot function and derivative side by side(initial guess=-1.8)

plt.figure(figsize=[15,5])


# 1st chart: cost function
plt.subplot(1,2,1)

plt.xlim([-2,2])
plt.ylim(0.5,5.5)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)
plt.plot(x_2,g(x_2),color='blue',linewidth=3, alpha = 0.8)
plt.scatter(list_x,g(np.array(list_x)),color='red',s=100,alpha=0.6)


# 2nd chart: derivative
plt.subplot(1,2,2)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('dg(x)',fontsize=16)
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=5,alpha=0.6)
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.5)


plt.show()

# %%
#calling gradient descent function

local_min,list_x,deriv_list = gradient_descent(derivative_func=dg,initial_guess=-0.1)

# Plot function and derivative side by side(initial guess=-0.1)

plt.figure(figsize=[15,5])


# 1st chart: cost function
plt.subplot(1,2,1)

plt.xlim([-2,2])
plt.ylim(0.5,5.5)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)
plt.plot(x_2,g(x_2),color='blue',linewidth=3, alpha = 0.8)
plt.scatter(list_x,g(np.array(list_x)),color='red',s=100,alpha=0.6)


# 2nd chart: derivative
plt.subplot(1,2,2)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('dg(x)',fontsize=16)
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=5,alpha=0.6)
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.5)


plt.show()

# %%
#calling gradient descent function

local_min,list_x,deriv_list = gradient_descent(derivative_func=dg,initial_guess=0)

# Plot function and derivative side by side(initial guess=0)

plt.figure(figsize=[15,5])


# 1st chart: cost function
plt.subplot(1,2,1)

plt.xlim([-2,2])
plt.ylim(0.5,5.5)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('g(x)',fontsize=16)
plt.plot(x_2,g(x_2),color='blue',linewidth=3, alpha = 0.8)
plt.scatter(list_x,g(np.array(list_x)),color='red',s=100,alpha=0.6)


# 2nd chart: derivative
plt.subplot(1,2,2)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('dg(x)',fontsize=16)
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=5,alpha=0.6)
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.5)


plt.show()

# %% [markdown]
# # Example - Divergence, Overflow and Python Tuples
# ## $$h(x)=x^5-2x^4+2$$

# %%
# Make data
x_3=np.linspace(start=-2.5,stop=2.5,num=1000)

def h(x):
    return x**5-2*x**4+2

def dh(x):
    return 5*x**4-8*x**3

# %%
#calling gradient descent function

local_min,list_x,deriv_list = gradient_descent(derivative_func=dh,initial_guess=0.2)

# Plot function and derivative side by side(initial guess=0.2)

plt.figure(figsize=[15,5])


# 1st chart: cost function
plt.subplot(1,2,1)

plt.xlim([-1.2,2.5])
plt.ylim(-1,4)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('h(x)',fontsize=16)
plt.plot(x_3,h(x_3),color='blue',linewidth=3, alpha = 0.8)
plt.scatter(list_x,h(np.array(list_x)),color='red',s=100,alpha=0.6)


# 2nd chart: derivative
plt.subplot(1,2,2)
plt.xlim(-1,2)
plt.ylim(-4,5)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('dh(x)',fontsize=16)
plt.plot(x_3,dh(x_3),color='skyblue',linewidth=5,alpha=0.6)
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.5)


plt.show()
print('local min occurs at:', local_min)
print('cost at this min is:',h(local_min))
print('number of steps:',len(list_x))
# Out:
# local min occurs at: 1.5989534547394717
# cost at this min is: -0.6214287992331258
# number of steps: 117

# %%
#calling gradient descent function

local_min,list_x,deriv_list = gradient_descent(derivative_func=dh,initial_guess=-0.2,max_iter=70)

# Plot function and derivative side by side(initial guess=-0.2)

plt.figure(figsize=[15,5])


# 1st chart: cost function
plt.subplot(1,2,1)

plt.xlim([-1.2,2.5])
plt.ylim(-1,4)
plt.title('cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('h(x)',fontsize=16)
plt.plot(x_3,h(x_3),color='blue',linewidth=3, alpha = 0.8)
plt.scatter(list_x,h(np.array(list_x)),color='red',s=100,alpha=0.6)


# 2nd chart: derivative
plt.subplot(1,2,2)
plt.xlim(-1,2)
plt.ylim(-4,5)
plt.grid()
plt.title('slope of the cost function',fontsize=17)
plt.xlabel('x',fontsize=16)
plt.ylabel('dh(x)',fontsize=16)
plt.plot(x_3,dh(x_3),color='skyblue',linewidth=5,alpha=0.6)
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.5)


plt.show()
print('local min occurs at:', local_min)
print('cost at this min is:',h(local_min))
print('number of steps:',len(list_x))
# Out:
# local min occurs at: -2071072.4470816324
# cost at this min is: -3.810455326061589e+31
# number of steps: 71

# %%
# 380,000,000,000,000,000,000,000,000,000,000

import sys
#help(sys)

#sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]'

# %%
type(h(local_min))
# Out:
# float

# %%
sys.float_info.max
# Out:
# 1.7976931348623157e+308
